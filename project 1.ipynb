# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
pd.pandas.set_option('display.max_rows',None)

# %%
df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x="Country",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Region",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Happiness Rank",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Happiness Score",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Standard Error",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Economy (GDP per Capita)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Family",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Health (Life Expectancy)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Freedom",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Trust (Government Corruption)",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Generosity",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Dystopia Residual'>

# %%
sns.scatterplot(x="Dystopia Residual",y="Dystopia Residual",data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Dystopia Residual'>

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.corr()['Dystopia Residual'].sort_values()
# Out:
# Happiness Rank                  -0.521999
# Generosity                      -0.101301
# Trust (Government Corruption)   -0.033105
# Health (Life Expectancy)         0.018979
# Economy (GDP per Capita)         0.040059
# Freedom                          0.062783
# Standard Error                   0.083981
# Family                           0.148117
# Happiness Score                  0.530474
# Dystopia Residual                1.000000
# Name: Dystopia Residual, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='Yellow',fmt='.2f'),
# Out:
# (<AxesSubplot:>,)

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# # Outliers checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=40
nrows=10

plt.figure(figsize=(ncol,ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    plt.tight_layout()

# %%
df.plot(kind='box',subplots='True',layout=(2,10),figsize=(20,20))
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.536818;0.065678x0.343182)
# Happiness Score                  AxesSubplot(0.203814,0.536818;0.065678x0.343182)
# Standard Error                   AxesSubplot(0.282627,0.536818;0.065678x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.361441,0.536818;0.065678x0.343182)
# Family                           AxesSubplot(0.440254,0.536818;0.065678x0.343182)
# Health (Life Expectancy)         AxesSubplot(0.519068,0.536818;0.065678x0.343182)
# Freedom                          AxesSubplot(0.597881,0.536818;0.065678x0.343182)
# Trust (Government Corruption)    AxesSubplot(0.676695,0.536818;0.065678x0.343182)
# Generosity                       AxesSubplot(0.755508,0.536818;0.065678x0.343182)
# Dystopia Residual                AxesSubplot(0.834322,0.536818;0.065678x0.343182)
# dtype: object

# %%
sns.boxplot(df[collist[i]],color='green',orient='h')
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.distplot(df["Happiness Rank"])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df["Happiness Score"])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df["Standard Error"])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df["Economy (GDP per Capita)"])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df["Family"])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df["Health (Life Expectancy)"])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df["Freedom"])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df["Trust (Government Corruption)"])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df["Generosity"])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df["Dystopia Residual"])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
df.corr()['Dystopia Residual']
# Out:
# Happiness Rank                  -0.521999
# Happiness Score                  0.530474
# Standard Error                   0.083981
# Economy (GDP per Capita)         0.040059
# Family                           0.148117
# Health (Life Expectancy)         0.018979
# Freedom                          0.062783
# Trust (Government Corruption)   -0.033105
# Generosity                      -0.101301
# Dystopia Residual                1.000000
# Name: Dystopia Residual, dtype: float64

# %%
df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
pf=pd.DataFrame([["-0.521999","Happiness Rank","No","Alot"],["0.083981","Standard Error","No","Alot"],["0.040059","Economy (GDP per Capita)","No","Alot"],["0.018979","Health (Life Expectancy)","No","Alot"],["0.062783","Freedom","No","Alot"],["-0.033105","Trust (Government Corruption)","No","Alot"]], columns=["Corelation With Dystopia Residual","Column Name","Normalised","Outliers"])

# %%
df=df.drop(['Country','Region'],axis=1)

# %%
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# 5                 6            7.406         0.03140
# 6                 7            7.378         0.02799
# 7                 8            7.364         0.03157
# 8                 9            7.286         0.03371
# 9                10            7.284         0.04083
# 10               11            7.278         0.03470
# 11               12            7.226         0.04454
# 12               13            7.200         0.03751
# 13               14            7.187         0.04176
# 14               15            7.119         0.03839
# 15               16            6.983         0.04076
# 16               17            6.946         0.03499
# ...

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 9

# %%
z.iloc[27]
# Out:
# Happiness Rank                   1.129016
# Happiness Score                  1.082256
# Standard Error                   0.859197
# Economy (GDP per Capita)         2.101026
# Family                           0.322476
# Health (Life Expectancy)         0.678336
# Freedom                          1.409878
# Trust (Government Corruption)    3.164619
# Generosity                       0.700286
# Dystopia Residual                0.982677
# Name: 27, dtype: float64

# %%
df_new=df[(z<3).all(axis=1)]
print("Old Dataframe",df.shape)
print("New Dataframe",df_new.shape)
print("total_dropped_rows",df.shape[0]-df_new.shape[0])
# Out:
# Old Dataframe (158, 10)
# New Dataframe (149, 10)
# total_dropped_rows 9

# %% [markdown]
# # Percentage data loss

# %%
loss_percent=(158-149)/158*100
print(loss_percent,'%')
# Out:
# 5.69620253164557 %

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %%
x
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# 5                 6            7.406         0.03140
# 6                 7            7.378         0.02799
# 7                 8            7.364         0.03157
# 8                 9            7.286         0.03371
# 9                10            7.284         0.04083
# 10               11            7.278         0.03470
# 11               12            7.226         0.04454
# 12               13            7.200         0.03751
# 13               14            7.187         0.04176
# 14               15            7.119         0.03839
# 15               16            6.983         0.04076
# 16               17            6.946         0.03499
# ...

# %%
y
# Out:
# 0      2.51738
# 1      2.70201
# 2      2.49204
# 3      2.46531
# 4      2.45176
# 5      2.61955
# 6      2.46570
# 7      2.37119
# 8      2.26425
# 9      2.26646
# 10     3.08854
# 11     3.17728
# 12     2.53320
# 13     3.60214
# 14     2.51011
# 15     3.26001
# 16     1.96961
# 17     1.97570
# 18     2.41484
# 19     2.24743
# 20     1.96994
# 21     2.47489
# 22     3.19131
# 23     1.88501
# 24     2.84848
# 25     2.11569
# 26     2.67585
# 28     2.21126
# 29     2.83600
# 30     2.67782
# 31     2.32142
# 32     2.85737
# 33     2.31945
# 34     2.43872
# 35     2.12367
# 36     1.64880
# 37     2.32323
# 38     1.87634
# 39     2.79094
# 41     3.03500
# 42     2.74255
# 43     2.23741
# 44     2.24639
# 45     1.68435
# 46     2.21978
# 47     2.53942
# 48     1.73797
# 49     2.02518
# 50     2.82334
# 51     3.10712
# 52     2.18896
# 53     2.24729
# 54     1.61583
# 55     2.44649
# 56     2.32407
# 57     2.59450
# 58     2.13090
# 59     1.86565
# ...

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-2.05151352,  1.82591163, -0.95033703, ...,  1.75498234,
#          1.81762514,  0.65957855],
#        [-1.99584442,  1.80625026,  0.37856182, ...,  1.44218195,
#          0.32967608,  1.56260401],
#        [-1.94524081,  1.7804847 , -1.04140135, ...,  1.6160368 ,
#          1.95339957,  0.97722591],
#        ...,
#        [ 1.53128908, -1.78998689, -1.32081011, ..., -1.26539516,
#         -0.19284339,  1.13425805],
#        [ 1.56626337, -2.05390645, -0.69272644, ...,  0.31812329,
#         -0.4344978 , -0.31207994],
#        [ 1.60111233, -2.56623507,  2.17876604, ..., -1.84989335,
#         -0.14727363, -0.17248608]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0   -0.266578
# 1   -0.017940
# 2   -0.031216
# 3   -0.140644
# 4   -0.148528
# 5   -0.190663
# 6   -0.076489
# 7    0.174593
# 8    0.025172
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-2.05151352,  1.82591163, -0.95033703, ...,  1.75498234,
#          1.81762514,  0.65957855],
#        [-1.99584442,  1.80625026,  0.37856182, ...,  1.44218195,
#          0.32967608,  1.56260401],
#        [-1.94524081,  1.7804847 , -1.04140135, ...,  1.6160368 ,
#          1.95339957,  0.97722591],
#        ...,
#        [ 1.53128908, -1.78998689, -1.32081011, ..., -1.26539516,
#         -0.19284339,  1.13425805],
#        [ 1.56626337, -2.05390645, -0.69272644, ...,  0.31812329,
#         -0.4344978 , -0.31207994],
#        [ 1.60111233, -2.56623507,  2.17876604, ..., -1.84989335,
#         -0.14727363, -0.17248608]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Splitting the Dataframe

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
train_x
# Out:
# array([[-1.23304206,  1.22199812,  1.34854064, ..., -0.07154344,
#         -0.01876079, -1.71965784],
#        [-1.4490994 ,  1.35949809, -0.28750304, ...,  0.36161699,
#          0.64719371, -0.68528712],
#        [-0.09181171,  0.19462739,  0.47624396, ..., -1.19214239,
#         -0.97365584,  0.55588667],
#        ...,
#        [-1.4818429 ,  1.46633113, -0.51072847, ...,  0.77795024,
#          0.50139864,  1.35820267],
#        [ 0.47050714, -0.39042842,  1.55304848, ..., -1.96947598,
#         -1.9274676 ,  0.27571299],
#        [ 0.66714286, -0.54545634, -1.18805124, ...,  0.22937319,
#          0.42303615,  0.11994353]])

# %%
train_y
# Out:
# 22     3.19131
# 15     3.26001
# 68     2.76579
# 11     3.17728
# 44     2.24639
# 108    2.51767
# 53     2.24729
# 28     2.21126
# 4      2.45176
# 33     2.31945
# 124    1.78555
# 88     1.62215
# 89     1.75360
# 16     1.96961
# 10     3.08854
# 84     2.63430
# 137    1.79293
# 148    1.94296
# 78     1.63794
# 111    1.95335
# 98     1.73799
# 107    2.04384
# 69     1.86984
# 0      2.51738
# 146    1.85100
# 70     1.76145
# 29     2.83600
# 42     2.74255
# 46     2.21978
# 62     2.09066
# 126    1.75873
# 24     2.84848
# 25     2.11569
# 23     1.88501
# 96     2.79832
# 41     3.03500
# 97     1.21305
# 143    1.87877
# 49     2.02518
# 99     1.34759
# 116    2.27513
# 34     2.43872
# 101    1.80101
# 151    1.46494
# 65     1.59888
# 87     1.26462
# 123    2.11773
# 55     2.44649
# 5      2.61955
# 154    1.63328
# 142    0.99895
# 51     3.10712
# 36     1.64880
# 83     1.86040
# 80     3.10709
# 35     2.12367
# 117    2.20857
# 7      2.37119
# ...

# %%
train_x.shape
# Out:
# (119, 9)

# %%
train_y.shape
# Out:
# (119,)

# %%
test_x.shape
# Out:
# (30, 9)

# %%
test_y.shape
# Out:
# (30,)

# %%
lm=LinearRegression()

# %%
lm.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
lm.score(train_x,train_y)
# Out:
# 0.9685392997415128

# %%
lm.coef_
# Out:
# array([-0.67365232,  0.43011937, -0.00716119, -0.39107017, -0.24732321,
#        -0.2477719 , -0.16396735, -0.06685076, -0.0978218 ])

# %%
lm.intercept_
# Out:
# 2.1215030095559007

# %%
pred=lm.predict(x_test)
print("Predicted value and actual value",pred,y_test)
# Out:
# Predicted value and actual value [1.6657282  1.66834012 2.78176785 1.95978168 2.35931783 2.10488641
#  1.45817167 1.86256043 2.25871585 1.23724301 2.54460563 2.22353492
#  2.39255655 2.77225281 1.84327562 1.74740343 2.38698519 2.35428025
#  1.92405071 2.67248557 2.85661354 2.32855388 1.65920317 3.16329494
#  1.50841457 1.23388507 2.91305522 2.67282209 1.630437   1.97714711] 138    1.68135
# 112    1.71956
# 61     2.75414
# 83     1.86040
# 7      2.37119
# 107    2.04384
# 145    1.38079
# 98     1.73799
# 122    2.51009
# 87     1.26462
# 34     2.43872
# 46     2.21978
# 56     2.32407
# 24     2.84848
# 38     1.87634
# 137    1.79293
# 114    2.44191
# 76     2.23270
# 16     1.96961
# 47     2.53942
# 42     2.74255
# 8      2.26425
# 88     1.62215
# 22     3.19131
# 65     1.59888
# 97     1.21305
# 93     3.05137
# 26     2.67585
# 45     1.68435
# 139    1.95812
# Name: Dystopia Residual, dtype: float64

# %%
predlm=lm.predict(x_test)
predlm
# Out:
# array([1.6657282 , 1.66834012, 2.78176785, 1.95978168, 2.35931783,
#        2.10488641, 1.45817167, 1.86256043, 2.25871585, 1.23724301,
#        2.54460563, 2.22353492, 2.39255655, 2.77225281, 1.84327562,
#        1.74740343, 2.38698519, 2.35428025, 1.92405071, 2.67248557,
#        2.85661354, 2.32855388, 1.65920317, 3.16329494, 1.50841457,
#        1.23388507, 2.91305522, 2.67282209, 1.630437  , 1.97714711])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,predlm)
# Out:
# 0.0071874278161849214

# %%
np.sqrt(mean_squared_error(y_test,predlm))
# Out:
# 0.08477869907108107

# %%
from sklearn.metrics import r2_score
print(r2_score(pred,y_test))
# Out:
# 0.9724986759557743
